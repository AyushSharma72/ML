# %% [markdown]
# # first time use notebook
#
# ## importing dataset using pandas

# %%
# pandas
import pandas as pd
df = pd.read_csv('final.csv') # read csv is a function in pandas and df is a varibale used to store it
# Out:
#      Unnamed: 0           STATE/UT  YEAR  POPULATION   MALES  FEMALES  \
# 0             0        A&N Islands  2001         356     193      163
# 1             1     Andhra Pradesh  2001       76210   38527    37683
# 2             2  Arunachal Pradesh  2001        1098     580      518
# 3             3              Assam  2001       26656   13777    12878
# 4             4              Bihar  2001       82999   43244    39755
# ..          ...                ...   ...         ...     ...      ...
# 463         463         Tamil Nadu  2013       68265   34248    34017
# 464         464            Tripura  2013        3700    1893     1807
# 465         465      Uttar Pradesh  2013      207739  109466    98273
# 466         466        Uttarakhand  2013       10224    5217     5006
# 467         467        West Bengal  2013       91122   46836    44287
#
#      MALES(per_100k)  FEMALES(per_100k)  TOTAL IPC CRIMES  \
# 0       54213.483146       45786.516854              1316
# ...
